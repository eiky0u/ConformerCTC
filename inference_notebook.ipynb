# %% [markdown]
# # Installations

# %%
#clone repo
# !git clone https://username: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@github.com//eiky0u/ConformerCTC.git
# Out:
# Cloning into 'ConformerCTC'...
# remote: Enumerating objects: 109, done.
# remote: Counting objects: 100% (109/109), done.
# remote: Compressing objects: 100% (98/98), done.
# remote: Total 109 (delta 17), reused 93 (delta 7), pack-reused 0 (from 0)
# Receiving objects: 100% (109/109), 10.72 MiB | 17.29 MiB/s, done.
# Resolving deltas: 100% (17/17), done.

# %%
#download model weights and example dataset
# !git clone https://huggingface.co/eikyou/Conformer
# Out:
# Cloning into 'Conformer'...
# remote: Enumerating objects: 13, done.
# remote: Counting objects: 100% (10/10), done.
# remote: Compressing objects: 100% (10/10), done.
# remote: Total 13 (delta 2), reused 0 (delta 0), pack-reused 3 (from 1)
# Unpacking objects: 100% (13/13), 4.93 KiB | 1.23 MiB/s, done.

# %%
#unzip dataset
# !unzip -o /kaggle/working/Conformer/example.zip -d /kaggle/working/dataset
# Out:
# Archive:  /kaggle/working/Conformer/example.zip
#    creating: /kaggle/working/dataset/audio/
#   inflating: /kaggle/working/dataset/audio/84-121123-0000.flac
#   inflating: /kaggle/working/dataset/audio/84-121123-0001.flac
#   inflating: /kaggle/working/dataset/audio/84-121123-0002.flac
#   inflating: /kaggle/working/dataset/audio/84-121123-0003.flac
#   inflating: /kaggle/working/dataset/audio/84-121123-0004.flac
#    creating: /kaggle/working/dataset/transcriptions/
#  extracting: /kaggle/working/dataset/transcriptions/84-121123-0000.txt
#   inflating: /kaggle/working/dataset/transcriptions/84-121123-0001.txt
#   inflating: /kaggle/working/dataset/transcriptions/84-121123-0002.txt
#   inflating: /kaggle/working/dataset/transcriptions/84-121123-0003.txt
#   inflating: /kaggle/working/dataset/transcriptions/84-121123-0004.txt

# %%
#install dependencies
# !pip install -r /kaggle/working/ConformerCTC/requirements.txt
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu121, https://pypi.org/simple
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 757.3/757.3 MB 1.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 27.2 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.4/3.4 MB 15.2 MB/s eta 0:00:0000:0100:01
# ...
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.4/41.4 kB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 59.6/59.6 kB 3.2 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
# WARNING: The candidate selected for download or install is a yanked version: 'transformers' candidate (version 4.57.0 at https://files.pythonhosted.org/packages/e5/2b/4d2708ac1ff5cd708b6548f4c5812d0ae40d1c28591c4c1c762b6dbdef2d/transformers-4.57.0-py3-none-any.whl (from https://pypi.org/simple/transformers/) (requires-python:>=3.9.0))
# ...

# %% [markdown]
# # Dataset config

# %%
# %%writefile /kaggle/working/ConformerCTC/src/configs/datasets/inference_example.yaml
# inference:
#   _target_: src.datasets.CustomDirAudioDataset
#   audio_dir: /kaggle/working/dataset/audio #path to your audio
#   transcription_dir: /kaggle/working/dataset/transcriptions #path to your transcriptions
#   instance_transforms: ${transforms.instance_transforms.inference}
# Out:
# Overwriting /kaggle/working/ConformerCTC/src/configs/datasets/inference_example.yaml

# %% [markdown]
# # Run inference

# %%
#run inference
# !python3 /kaggle/working/ConformerCTC/inference.py --config-name inference_example inferencer.from_pretrained="/kaggle/working/Conformer/clean_training.pth"
# Out:
# DATASETS PARTITIONS: ['inference']
# ConformerCTC(
#   (encoder): ConformerEncoder(
#     (subsampling): ConvSubsampling2D(
#       (conv): Sequential(
#         (0): Conv2d(1, 64, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (1): ReLU()
#         (2): Conv2d(64, 128, kernel_size=(3, 3), stride=(2, 2), padding=(1, 1))
#         (3): ReLU()
#       )
#       (out_proj): Linear(in_features=2048, out_features=128, bias=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (blocks): ModuleList(
#       (0-5): 6 x ConformerBlock(
#         (ff1): FeedForward(
#           (net): Sequential(
#             (0): LayerNorm((128,), eps=1e-05, elementwise_affine=True)
#             (1): Linear(in_features=128, out_features=512, bias=True)
#             (2): SiLU()
#             (3): Dropout(p=0.1, inplace=False)
#             (4): Linear(in_features=512, out_features=128, bias=True)
#             (5): Dropout(p=0.1, inplace=False)
#           )
#         )
# ...
